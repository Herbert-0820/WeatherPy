# %%
# Import dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
# Import the API key.
from config import weather_api_key
# Import the requests library.
import requests

## Imports that we used in the modules, but were not needed for this deliverable.
# import matplotlib.pyplot as plt
# Import the time module.
# import time
# Import the datetime module from the datetime library.
# from datetime import datetime
# Import linear regression from the SciPy stats module.
# from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Starting URL for Weather Map API Call.
url = weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b06d83a68be15ce3898f16100941ccf7

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | birao
# Processing Record 2 of Set 1 | beloha
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | ustynivka
# Processing Record 6 of Set 1 | dargaville
# Processing Record 7 of Set 1 | komsomolskiy
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | natal
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | maumere
# Processing Record 13 of Set 1 | talnakh
# Processing Record 14 of Set 1 | mulege
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | arica
# Processing Record 18 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 1 | balao
# Processing Record 20 of Set 1 | hasaki
# Processing Record 21 of Set 1 | georgetown
# Processing Record 22 of Set 1 | atar
# Processing Record 23 of Set 1 | rio gallegos
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | macae
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | kulhudhuffushi
# Processing Record 30 of Set 1 | kondinskoye
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | inta
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | upernavik
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | beocin
# Processing Record 38 of Set 1 | geraldton
# Processing Record 39 of Set 1 | provideniya
# Processing Record 40 of Set 1 | kavieng
# Processing Record 41 of Set 1 | olinda
# Processing Record 42 of Set 1 | haines junction
# Processing Record 43 of Set 1 | horsham
# Processing Record 44 of Set 1 | simbach
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | nova granada
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | kannod
# Processing Record 50 of Set 1 | brae
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | norman wells
# Processing Record 3 of Set 2 | bafoulabe
# Processing Record 4 of Set 2 | severo-yeniseyskiy
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | turayf
# Processing Record 7 of Set 2 | kasungu
# Processing Record 8 of Set 2 | svetlyy
# Processing Record 9 of Set 2 | lata
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | voznesenye
# Processing Record 12 of Set 2 | thompson
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | bay roberts
# Processing Record 16 of Set 2 | alta floresta
# Processing Record 17 of Set 2 | khatanga
# Processing Record 18 of Set 2 | san carlos de bariloche
# Processing Record 19 of Set 2 | kavaratti
# Processing Record 20 of Set 2 | lebu
# Processing Record 21 of Set 2 | piombino
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 | new norfolk
# Processing Record 24 of Set 2 | novovyazniki
# Processing Record 25 of Set 2 | jamestown
# Processing Record 26 of Set 2 | sinnamary
# Processing Record 27 of Set 2 | necochea
# Processing Record 28 of Set 2 | port alfred
# Processing Record 29 of Set 2 | isangel
# Processing Record 30 of Set 2 | mahebourg
# Processing Record 31 of Set 2 | severo-kurilsk
# Processing Record 32 of Set 2 | tasiilaq
# Processing Record 33 of Set 2 | gisborne
# Processing Record 34 of Set 2 | mandalgovi
# Processing Record 35 of Set 2 | vostok
# Processing Record 36 of Set 2 | ilulissat
# Processing Record 37 of Set 2 | tahta
# Processing Record 38 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 2 | mafinga
# Processing Record 40 of Set 2 | carnarvon
# Processing Record 41 of Set 2 | kruisfontein
# Processing Record 42 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | colares
# Processing Record 45 of Set 2 | saint george
# Processing Record 46 of Set 2 | faanui
# Processing Record 47 of Set 2 | yulara
# Processing Record 48 of Set 2 | bandarbeyla
# Processing Record 49 of Set 2 | manthani
# Processing Record 50 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 3 | comodoro rivadavia
# Processing Record 3 of Set 3 | port elizabeth
# Processing Record 4 of Set 3 | esperance
# Processing Record 5 of Set 3 | arraial do cabo
# Processing Record 6 of Set 3 | avera
# Processing Record 7 of Set 3 | namibe
# Processing Record 8 of Set 3 | dukat
# Processing Record 9 of Set 3 | saryozek
# Processing Record 10 of Set 3 | srednekolymsk
# Processing Record 11 of Set 3 | port macquarie
# Processing Record 12 of Set 3 | bredasdorp
# Processing Record 13 of Set 3 | hlotse
# Processing Record 14 of Set 3 | sitka
# Processing Record 15 of Set 3 | ancud
# Processing Record 16 of Set 3 | kodinsk
# Processing Record 17 of Set 3 | sunrise manor
# Processing Record 18 of Set 3 | ahipara
# Processing Record 19 of Set 3 | tuktoyaktuk
# Processing Record 20 of Set 3 | pisco
# Processing Record 21 of Set 3 | richards bay
# Processing Record 22 of Set 3 | ostrovnoy
# Processing Record 23 of Set 3 | acarigua
# Processing Record 24 of Set 3 | pemangkat
# Processing Record 25 of Set 3 | porosozero
# Processing Record 26 of Set 3 | bonthe
# Processing Record 27 of Set 3 | inhambane
# Processing Record 28 of Set 3 | arbagar
# Processing Record 29 of Set 3 | ondjiva
# Processing Record 30 of Set 3 | hienghene
# Processing Record 31 of Set 3 | vidim
# Processing Record 32 of Set 3 | tura
# Processing Record 33 of Set 3 | rawson
# Processing Record 34 of Set 3 | sechura
# Processing Record 35 of Set 3 | quatre cocos
# Processing Record 36 of Set 3 | filingue
# Processing Record 37 of Set 3 | nome
# Processing Record 38 of Set 3 | abu dhabi
# Processing Record 39 of Set 3 | taldan
# Processing Record 40 of Set 3 | nouadhibou
# Processing Record 41 of Set 3 | victoria
# Processing Record 42 of Set 3 | souillac
# Processing Record 43 of Set 3 | kununurra
# Processing Record 44 of Set 3 | nikolskoye
# Processing Record 45 of Set 3 | tevaitoa
# Processing Record 46 of Set 3 | longyearbyen
# Processing Record 47 of Set 3 | vila franca do campo
# Processing Record 48 of Set 3 | luderitz
# Processing Record 49 of Set 3 | mayo
# Processing Record 50 of Set 3 | butaritari
# Processing Record 1 of Set 4 | cabo san lucas
# Processing Record 2 of Set 4 | avarua
# Processing Record 3 of Set 4 | tocopilla
# Processing Record 4 of Set 4 | jieshi
# Processing Record 5 of Set 4 | san patricio
# Processing Record 6 of Set 4 | zdzieszowice
# Processing Record 7 of Set 4 | enshi
# Processing Record 8 of Set 4 | qaanaaq
# Processing Record 9 of Set 4 | barrow
# Processing Record 10 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 4 | cherskiy
# Processing Record 13 of Set 4 | hay river
# Processing Record 14 of Set 4 | iqaluit
# Processing Record 15 of Set 4 | chuy
# Processing Record 16 of Set 4 | chivay
# Processing Record 17 of Set 4 | poum
# Processing Record 18 of Set 4 | fuengirola
# Processing Record 19 of Set 4 | moron
# Processing Record 20 of Set 4 | chokurdakh
# Processing Record 21 of Set 4 | gazi
# Processing Record 22 of Set 4 | pevek
# Processing Record 23 of Set 4 | kodiak
# Processing Record 24 of Set 4 | kimbe
# Processing Record 25 of Set 4 | dunedin
# Processing Record 26 of Set 4 | kieta
# Processing Record 27 of Set 4 | pendleton
# Processing Record 28 of Set 4 | baiyin
# Processing Record 29 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 30 of Set 4 | suntar
# Processing Record 31 of Set 4 | dingle
# Processing Record 32 of Set 4 | adrar
# Processing Record 33 of Set 4 | itoman
# Processing Record 34 of Set 4 | bajo baudo
# City not found. Skipping...
# Processing Record 35 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 36 of Set 4 | chicama
# Processing Record 37 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 4 | aljezur
# Processing Record 39 of Set 4 | limbang
# Processing Record 40 of Set 4 | roma
# Processing Record 41 of Set 4 | flin flon
# Processing Record 42 of Set 4 | burnie
# Processing Record 43 of Set 4 | svetlogorsk
# Processing Record 44 of Set 4 | phuket
# Processing Record 45 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 4 | oksfjord
# Processing Record 47 of Set 4 | lavrentiya
# Processing Record 48 of Set 4 | sao filipe
# Processing Record 49 of Set 4 | katsuura
# Processing Record 50 of Set 4 | port hardy
# Processing Record 1 of Set 5 | krasnoselkup
# Processing Record 2 of Set 5 | ola
# Processing Record 3 of Set 5 | usinsk
# Processing Record 4 of Set 5 | irgakly
# Processing Record 5 of Set 5 | upata
# Processing Record 6 of Set 5 | tautira
# Processing Record 7 of Set 5 | montbrison
# Processing Record 8 of Set 5 | kalabo
# Processing Record 9 of Set 5 | grootfontein
# Processing Record 10 of Set 5 | mau aima
# City not found. Skipping...
# Processing Record 11 of Set 5 | balabac
# Processing Record 12 of Set 5 | hualmay
# Processing Record 13 of Set 5 | bonavista
# Processing Record 14 of Set 5 | kalmunai
# Processing Record 15 of Set 5 | saldanha
# Processing Record 16 of Set 5 | ponta do sol
# Processing Record 17 of Set 5 | iskele
# Processing Record 18 of Set 5 | arroyo
# Processing Record 19 of Set 5 | east london
# Processing Record 20 of Set 5 | shar
# Processing Record 21 of Set 5 | santa maria da boa vista
# Processing Record 22 of Set 5 | beira
# Processing Record 23 of Set 5 | kahului
# Processing Record 24 of Set 5 | hithadhoo
# Processing Record 25 of Set 5 | bengkulu
# Processing Record 26 of Set 5 | puerto carreno
# Processing Record 27 of Set 5 | blyth
# Processing Record 28 of Set 5 | narrabri
# Processing Record 29 of Set 5 | chimbote
# Processing Record 30 of Set 5 | baruun-urt
# Processing Record 31 of Set 5 | sur
# Processing Record 32 of Set 5 | olga
# Processing Record 33 of Set 5 | pangkalanbuun
# Processing Record 34 of Set 5 | liuzhou
# Processing Record 35 of Set 5 | salalah
# Processing Record 36 of Set 5 | porto murtinho
# Processing Record 37 of Set 5 | saskylakh
# Processing Record 38 of Set 5 | ust-tsilma
# Processing Record 39 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 5 | yabelo
# Processing Record 41 of Set 5 | rio grande
# Processing Record 42 of Set 5 | pijijiapan
# Processing Record 43 of Set 5 | port blair
# Processing Record 44 of Set 5 | constitucion
# Processing Record 45 of Set 5 | pandan
# Processing Record 46 of Set 5 | kaitangata
# Processing Record 47 of Set 5 | sola
# Processing Record 48 of Set 5 | muzhi
# Processing Record 49 of Set 5 | clyde river
# Processing Record 50 of Set 5 | fortuna
# Processing Record 1 of Set 6 | muros
# Processing Record 2 of Set 6 | saint-augustin
# Processing Record 3 of Set 6 | hamilton
# Processing Record 4 of Set 6 | clarence town
# Processing Record 5 of Set 6 | suluq
# Processing Record 6 of Set 6 | sobolevo
# Processing Record 7 of Set 6 | leningradskiy
# Processing Record 8 of Set 6 | raudeberg
# Processing Record 9 of Set 6 | fort nelson
# Processing Record 10 of Set 6 | marawi
# Processing Record 11 of Set 6 | bambous virieux
# Processing Record 12 of Set 6 | payson
# Processing Record 13 of Set 6 | khasan
# Processing Record 14 of Set 6 | mandalon
# Processing Record 15 of Set 6 | plouzane
# Processing Record 16 of Set 6 | guerrero negro
# Processing Record 17 of Set 6 | bavly
# Processing Record 18 of Set 6 | ulkan
# Processing Record 19 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 6 | luanda
# Processing Record 21 of Set 6 | santiago
# Processing Record 22 of Set 6 | bathsheba
# Processing Record 23 of Set 6 | athabasca
# Processing Record 24 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 25 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 6 | tabora
# Processing Record 27 of Set 6 | meinung
# City not found. Skipping...
# Processing Record 28 of Set 6 | meulaboh
# Processing Record 29 of Set 6 | beinamar
# Processing Record 30 of Set 6 | thinadhoo
# Processing Record 31 of Set 6 | tomarovka
# Processing Record 32 of Set 6 | naliya
# Processing Record 33 of Set 6 | angoram
# Processing Record 34 of Set 6 | cubara
# Processing Record 35 of Set 6 | klaksvik
# Processing Record 36 of Set 6 | ballina
# Processing Record 37 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 6 | san jose
# Processing Record 39 of Set 6 | khed brahma
# Processing Record 40 of Set 6 | trairi
# Processing Record 41 of Set 6 | hambantota
# Processing Record 42 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 6 | wattegama
# Processing Record 44 of Set 6 | iquique
# Processing Record 45 of Set 6 | kitimat
# Processing Record 46 of Set 6 | ulaangom
# Processing Record 47 of Set 6 | lagoa
# Processing Record 48 of Set 6 | doha
# Processing Record 49 of Set 6 | lleida
# Processing Record 50 of Set 6 | egvekinot
# Processing Record 1 of Set 7 | faya
# Processing Record 2 of Set 7 | mackenzie
# Processing Record 3 of Set 7 | ghanzi
# Processing Record 4 of Set 7 | lake havasu city
# Processing Record 5 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 6 of Set 7 | coquimbo
# Processing Record 7 of Set 7 | tukrah
# Processing Record 8 of Set 7 | bud
# Processing Record 9 of Set 7 | meget
# Processing Record 10 of Set 7 | maceio
# Processing Record 11 of Set 7 | iracoubo
# Processing Record 12 of Set 7 | san fernando
# Processing Record 13 of Set 7 | grindavik
# Processing Record 14 of Set 7 | yichang
# Processing Record 15 of Set 7 | takoradi
# Processing Record 16 of Set 7 | saint-joseph
# Processing Record 17 of Set 7 | muleba
# Processing Record 18 of Set 7 | luba
# Processing Record 19 of Set 7 | shimoda
# Processing Record 20 of Set 7 | trelew
# Processing Record 21 of Set 7 | bubaque
# Processing Record 22 of Set 7 | kaeo
# Processing Record 23 of Set 7 | snezhnogorsk
# Processing Record 24 of Set 7 | batie
# Processing Record 25 of Set 7 | ambilobe
# Processing Record 26 of Set 7 | iskateley
# Processing Record 27 of Set 7 | praia da vitoria
# Processing Record 28 of Set 7 | tiruvottiyur
# City not found. Skipping...
# Processing Record 29 of Set 7 | daru
# Processing Record 30 of Set 7 | toora-khem
# Processing Record 31 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 7 | adelaide
# Processing Record 33 of Set 7 | oistins
# Processing Record 34 of Set 7 | beringovskiy
# Processing Record 35 of Set 7 | imbituba
# Processing Record 36 of Set 7 | grand gaube
# Processing Record 37 of Set 7 | havelock
# Processing Record 38 of Set 7 | bilma
# Processing Record 39 of Set 7 | havre-saint-pierre
# Processing Record 40 of Set 7 | tilichiki
# Processing Record 41 of Set 7 | asheville
# Processing Record 42 of Set 7 | abu samrah
# Processing Record 43 of Set 7 | aswan
# Processing Record 44 of Set 7 | neryungri
# Processing Record 45 of Set 7 | margate
# Processing Record 46 of Set 7 | oussouye
# Processing Record 47 of Set 7 | podgornoye
# Processing Record 48 of Set 7 | san cristobal
# Processing Record 49 of Set 7 | mitsamiouli
# Processing Record 50 of Set 7 | maghama
# City not found. Skipping...
# Processing Record 1 of Set 8 | manta
# Processing Record 2 of Set 8 | ponta delgada
# Processing Record 3 of Set 8 | sistranda
# Processing Record 4 of Set 8 | airai
# Processing Record 5 of Set 8 | cabedelo
# Processing Record 6 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 7 of Set 8 | mago
# Processing Record 8 of Set 8 | bonfim
# Processing Record 9 of Set 8 | novogurovskiy
# Processing Record 10 of Set 8 | port lincoln
# Processing Record 11 of Set 8 | jacqueville
# Processing Record 12 of Set 8 | makakilo city
# Processing Record 13 of Set 8 | umea
# Processing Record 14 of Set 8 | asfi
# Processing Record 15 of Set 8 | heishan
# Processing Record 16 of Set 8 | broome
# Processing Record 17 of Set 8 | niono
# Processing Record 18 of Set 8 | kamina
# Processing Record 19 of Set 8 | vanimo
# Processing Record 20 of Set 8 | kabare
# Processing Record 21 of Set 8 | gasa
# Processing Record 22 of Set 8 | mehamn
# Processing Record 23 of Set 8 | vila velha
# Processing Record 24 of Set 8 | morondava
# Processing Record 25 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 8 | lufilufi
# Processing Record 27 of Set 8 | dezful
# Processing Record 28 of Set 8 | vestmannaeyjar
# Processing Record 29 of Set 8 | kharan
# Processing Record 30 of Set 8 | angren
# Processing Record 31 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 8 | torbay
# Processing Record 33 of Set 8 | seoul
# Processing Record 34 of Set 8 | hearst
# Processing Record 35 of Set 8 | ravne
# Processing Record 36 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 8 | zaragoza
# Processing Record 38 of Set 8 | puerto del rosario
# Processing Record 39 of Set 8 | daoukro
# Processing Record 40 of Set 8 | tambul
# City not found. Skipping...
# Processing Record 41 of Set 8 | tabou
# Processing Record 42 of Set 8 | pombia
# Processing Record 43 of Set 8 | weihai
# Processing Record 44 of Set 8 | nizwa
# Processing Record 45 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 46 of Set 8 | sala
# Processing Record 47 of Set 8 | carlsbad
# Processing Record 48 of Set 8 | lisieux
# Processing Record 49 of Set 8 | grand-lahou
# Processing Record 50 of Set 8 | westport
# Processing Record 1 of Set 9 | ambon
# Processing Record 2 of Set 9 | minudasht
# Processing Record 3 of Set 9 | surgut
# Processing Record 4 of Set 9 | niquero
# Processing Record 5 of Set 9 | olafsvik
# Processing Record 6 of Set 9 | maralal
# Processing Record 7 of Set 9 | zhigansk
# Processing Record 8 of Set 9 | kloulklubed
# Processing Record 9 of Set 9 | bahia honda
# Processing Record 10 of Set 9 | vila
# Processing Record 11 of Set 9 | karwar
# Processing Record 12 of Set 9 | chapais
# Processing Record 13 of Set 9 | ibra
# Processing Record 14 of Set 9 | narsaq
# Processing Record 15 of Set 9 | wajima
# Processing Record 16 of Set 9 | mendi
# Processing Record 17 of Set 9 | tessalit
# Processing Record 18 of Set 9 | paamiut
# Processing Record 19 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 20 of Set 9 | kasongo
# Processing Record 21 of Set 9 | shubarshi
# Processing Record 22 of Set 9 | biak
# Processing Record 23 of Set 9 | hami
# Processing Record 24 of Set 9 | honiara
# Processing Record 25 of Set 9 | odienne
# Processing Record 26 of Set 9 | saint anthony
# Processing Record 27 of Set 9 | mindelo
# Processing Record 28 of Set 9 | druzhba
# Processing Record 29 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 9 | owo
# Processing Record 31 of Set 9 | palembang
# Processing Record 32 of Set 9 | williamsport
# Processing Record 33 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 9 | djambala
# Processing Record 35 of Set 9 | bethanien
# Processing Record 36 of Set 9 | payo
# Processing Record 37 of Set 9 | el mante
# Processing Record 38 of Set 9 | changde
# Processing Record 39 of Set 9 | road town
# Processing Record 40 of Set 9 | camana
# Processing Record 41 of Set 9 | roros
# Processing Record 42 of Set 9 | zubtsov
# Processing Record 43 of Set 9 | lorengau
# Processing Record 44 of Set 9 | nanortalik
# Processing Record 45 of Set 9 | lima
# Processing Record 46 of Set 9 | labunista
# Processing Record 47 of Set 9 | vaitape
# Processing Record 48 of Set 9 | ormara
# Processing Record 49 of Set 9 | luwuk
# Processing Record 50 of Set 9 | laki
# Processing Record 1 of Set 10 | arani
# Processing Record 2 of Set 10 | urulga
# City not found. Skipping...
# Processing Record 3 of Set 10 | port keats
# Processing Record 4 of Set 10 | acarau
# Processing Record 5 of Set 10 | ibotirama
# Processing Record 6 of Set 10 | remerschen
# Processing Record 7 of Set 10 | kibala
# Processing Record 8 of Set 10 | acapulco
# Processing Record 9 of Set 10 | campobasso
# Processing Record 10 of Set 10 | villa carlos paz
# Processing Record 11 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 12 of Set 10 | cidreira
# Processing Record 13 of Set 10 | cayenne
# Processing Record 14 of Set 10 | kvitok
# Processing Record 15 of Set 10 | uyuni
# Processing Record 16 of Set 10 | cockburn town
# Processing Record 17 of Set 10 | auki
# Processing Record 18 of Set 10 | los llanos de aridane
# Processing Record 19 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 10 | chulumani
# Processing Record 21 of Set 10 | gushikawa
# Processing Record 22 of Set 10 | mahon
# Processing Record 23 of Set 10 | tupaciguara
# Processing Record 24 of Set 10 | aksarka
# Processing Record 25 of Set 10 | yar-sale
# Processing Record 26 of Set 10 | hengshui
# Processing Record 27 of Set 10 | ozernovskiy
# Processing Record 28 of Set 10 | fayaoue
# Processing Record 29 of Set 10 | caluquembe
# Processing Record 30 of Set 10 | tymovskoye
# Processing Record 31 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 32 of Set 10 | pimenta bueno
# Processing Record 33 of Set 10 | mogadishu
# Processing Record 34 of Set 10 | sorong
# Processing Record 35 of Set 10 | atwater
# Processing Record 36 of Set 10 | jacareacanga
# Processing Record 37 of Set 10 | mount gambier
# Processing Record 38 of Set 10 | portland
# Processing Record 39 of Set 10 | carutapera
# Processing Record 40 of Set 10 | brasilia de minas
# Processing Record 41 of Set 10 | campestre
# Processing Record 42 of Set 10 | pierre
# Processing Record 43 of Set 10 | nola
# Processing Record 44 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 10 | caldwell
# Processing Record 46 of Set 10 | ilhabela
# Processing Record 47 of Set 10 | tateyama
# Processing Record 48 of Set 10 | waingapu
# Processing Record 49 of Set 10 | mattru
# Processing Record 50 of Set 10 | morro bay
# Processing Record 1 of Set 11 | alexandria
# Processing Record 2 of Set 11 | saint-paul
# Processing Record 3 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 11 | matara
# Processing Record 5 of Set 11 | cibitoke
# Processing Record 6 of Set 11 | samarai
# Processing Record 7 of Set 11 | mikun
# Processing Record 8 of Set 11 | zyryanovsk
# Processing Record 9 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 10 of Set 11 | ewa beach
# Processing Record 11 of Set 11 | kautokeino
# Processing Record 12 of Set 11 | naze
# Processing Record 13 of Set 11 | emerald
# Processing Record 14 of Set 11 | maniitsoq
# Processing Record 15 of Set 11 | pangai
# Processing Record 16 of Set 11 | tezu
# Processing Record 17 of Set 11 | pinega
# Processing Record 18 of Set 11 | rudnyy
# Processing Record 19 of Set 11 | ercis
# Processing Record 20 of Set 11 | berlevag
# Processing Record 21 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 11 | ayr
# Processing Record 23 of Set 11 | pangnirtung
# Processing Record 24 of Set 11 | kanevskaya
# Processing Record 25 of Set 11 | gamba
# Processing Record 26 of Set 11 | riviere-au-renard
# Processing Record 27 of Set 11 | ausa
# Processing Record 28 of Set 11 | de-kastri
# Processing Record 29 of Set 11 | lingao
# Processing Record 30 of Set 11 | ocampo
# Processing Record 31 of Set 11 | lompoc
# Processing Record 32 of Set 11 | erzurum
# Processing Record 33 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 11 | mocuba
# Processing Record 35 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 11 | la libertad
# Processing Record 37 of Set 11 | cherat
# Processing Record 38 of Set 11 | beckley
# Processing Record 39 of Set 11 | maningrida
# Processing Record 40 of Set 11 | fredericksburg
# Processing Record 41 of Set 11 | dunmore town
# Processing Record 42 of Set 11 | whitianga
# Processing Record 43 of Set 11 | sabang
# Processing Record 44 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 45 of Set 11 | babushkin
# Processing Record 46 of Set 11 | waddan
# Processing Record 47 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 48 of Set 11 | sonqor
# Processing Record 49 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 50 of Set 11 | ampanihy
# Processing Record 1 of Set 12 | tuatapere
# Processing Record 2 of Set 12 | mawlaik
# Processing Record 3 of Set 12 | alofi
# Processing Record 4 of Set 12 | damme
# Processing Record 5 of Set 12 | sochi
# Processing Record 6 of Set 12 | vao
# Processing Record 7 of Set 12 | amahai
# Processing Record 8 of Set 12 | prince rupert
# Processing Record 9 of Set 12 | rurrenabaque
# Processing Record 10 of Set 12 | samashki
# Processing Record 11 of Set 12 | shellbrook
# Processing Record 12 of Set 12 | kawalu
# Processing Record 13 of Set 12 | asau
# Processing Record 14 of Set 12 | tucumcari
# Processing Record 15 of Set 12 | igarape-miri
# City not found. Skipping...
# Processing Record 16 of Set 12 | naryan-mar
# Processing Record 17 of Set 12 | yeppoon
# Processing Record 18 of Set 12 | bagnolo mella
# Processing Record 19 of Set 12 | lasa
# Processing Record 20 of Set 12 | tommot
# Processing Record 21 of Set 12 | hofn
# Processing Record 22 of Set 12 | parkes
# Processing Record 23 of Set 12 | hirara
# Processing Record 24 of Set 12 | marsa matruh
# Processing Record 25 of Set 12 | tres arroyos
# Processing Record 26 of Set 12 | ust-kuyga
# Processing Record 27 of Set 12 | nchelenge
# Processing Record 28 of Set 12 | chililabombwe
# Processing Record 29 of Set 12 | deputatskiy
# Processing Record 30 of Set 12 | jacksonville
# Processing Record 31 of Set 12 | linhares
# Processing Record 32 of Set 12 | halifax
# Processing Record 33 of Set 12 | paso de los toros
# Processing Record 34 of Set 12 | fukue
# Processing Record 35 of Set 12 | roald
# Processing Record 36 of Set 12 | rozkishne
# Processing Record 37 of Set 12 | lindas
# Processing Record 38 of Set 12 | vanavara
# Processing Record 39 of Set 12 | noumea
# Processing Record 40 of Set 12 | limay
# Processing Record 41 of Set 12 | toftir
# City not found. Skipping...
# Processing Record 42 of Set 12 | oudtshoorn
# Processing Record 43 of Set 12 | ishigaki
# Processing Record 44 of Set 12 | lanigan
# Processing Record 45 of Set 12 | moindou
# Processing Record 46 of Set 12 | erzin
# Processing Record 47 of Set 12 | kosh-agach
# Processing Record 48 of Set 12 | lumeje
# Processing Record 49 of Set 12 | padang
# Processing Record 50 of Set 12 | lambarene
# Processing Record 1 of Set 13 | buraydah
# Processing Record 2 of Set 13 | huilong
# Processing Record 3 of Set 13 | ocos
# Processing Record 4 of Set 13 | mishan
# Processing Record 5 of Set 13 | viransehir
# Processing Record 6 of Set 13 | ballitoville
# Processing Record 7 of Set 13 | visnes
# Processing Record 8 of Set 13 | carmen
# Processing Record 9 of Set 13 | talcahuano
# Processing Record 10 of Set 13 | chapulco
# Processing Record 11 of Set 13 | piacabucu
# Processing Record 12 of Set 13 | sao joao da barra
# Processing Record 13 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 13 | camden
# Processing Record 15 of Set 13 | guilin
# Processing Record 16 of Set 13 | rio cuarto
# Processing Record 17 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 18 of Set 13 | barcelos
# Processing Record 19 of Set 13 | slave lake
# Processing Record 20 of Set 13 | zakamensk
# Processing Record 21 of Set 13 | powell
# Processing Record 22 of Set 13 | ingham
# Processing Record 23 of Set 13 | te anau
# Processing Record 24 of Set 13 | saint-francois
# Processing Record 25 of Set 13 | camacha
# Processing Record 26 of Set 13 | coihaique
# Processing Record 27 of Set 13 | tulun
# Processing Record 28 of Set 13 | mount pleasant
# Processing Record 29 of Set 13 | zhaoyang
# Processing Record 30 of Set 13 | gallup
# Processing Record 31 of Set 13 | morehead
# Processing Record 32 of Set 13 | banda aceh
# Processing Record 33 of Set 13 | hokitika
# Processing Record 34 of Set 13 | bara
# Processing Record 35 of Set 13 | henties bay
# Processing Record 36 of Set 13 | pacific grove
# Processing Record 37 of Set 13 | frontera
# Processing Record 38 of Set 13 | manokwari
# Processing Record 39 of Set 13 | nampula
# Processing Record 40 of Set 13 | daxian
# City not found. Skipping...
# Processing Record 41 of Set 13 | dire
# Processing Record 42 of Set 13 | aklavik
# Processing Record 43 of Set 13 | verkhnevilyuysk
# Processing Record 44 of Set 13 | chokwe
# Processing Record 45 of Set 13 | puteyets
# Processing Record 46 of Set 13 | zwedru
# Processing Record 47 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 13 | challans
# Processing Record 49 of Set 13 | lukovetskiy
# Processing Record 50 of Set 13 | cairns
# Processing Record 1 of Set 14 | saint-pierre
# Processing Record 2 of Set 14 | pedregulho
# Processing Record 3 of Set 14 | magadan
# Processing Record 4 of Set 14 | ksenyevka
# City not found. Skipping...
# Processing Record 5 of Set 14 | denpasar
# Processing Record 6 of Set 14 | phan thiet
# Processing Record 7 of Set 14 | igbo ora
# Processing Record 8 of Set 14 | xitla
# City not found. Skipping...
# Processing Record 9 of Set 14 | moshenskoye
# Processing Record 10 of Set 14 | nantucket
# Processing Record 11 of Set 14 | saumur
# Processing Record 12 of Set 14 | chitral
# Processing Record 13 of Set 14 | lugovoy
# Processing Record 14 of Set 14 | linxia
# Processing Record 15 of Set 14 | bagdarin
# Processing Record 16 of Set 14 | staraya russa
# Processing Record 17 of Set 14 | sao jose da coroa grande
# Processing Record 18 of Set 14 | kaniama
# Processing Record 19 of Set 14 | antofagasta
# Processing Record 20 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 14 | sona
# Processing Record 22 of Set 14 | nago
# Processing Record 23 of Set 14 | labelle
# Processing Record 24 of Set 14 | olbia
# Processing Record 25 of Set 14 | zapadnaya dvina
# Processing Record 26 of Set 14 | sept-iles
# Processing Record 27 of Set 14 | yumen
# Processing Record 28 of Set 14 | ndola
# Processing Record 29 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 30 of Set 14 | nagua
# Processing Record 31 of Set 14 | kristiinankaupunki
# Processing Record 32 of Set 14 | ruteng
# Processing Record 33 of Set 14 | kenai
# Processing Record 34 of Set 14 | murray bridge
# Processing Record 35 of Set 14 | salym
# Processing Record 36 of Set 14 | zhengjiatun
# Processing Record 37 of Set 14 | vestmanna
# Processing Record 38 of Set 14 | solnechnyy
# Processing Record 39 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 40 of Set 14 | kankon
# Processing Record 41 of Set 14 | taoudenni
# Processing Record 42 of Set 14 | ferry pass
# Processing Record 43 of Set 14 | kokopo
# Processing Record 44 of Set 14 | plettenberg bay
# Processing Record 45 of Set 14 | jishou
# Processing Record 46 of Set 14 | austin
# Processing Record 47 of Set 14 | mapimi
# Processing Record 48 of Set 14 | celestun
# Processing Record 49 of Set 14 | palu
# Processing Record 50 of Set 14 | hays
# Processing Record 1 of Set 15 | port-gentil
# Processing Record 2 of Set 15 | dhidhdhoo
# Processing Record 3 of Set 15 | awjilah
# Processing Record 4 of Set 15 | maldonado
# Processing Record 5 of Set 15 | ngunguru
# Processing Record 6 of Set 15 | litoral del san juan
# City not found. Skipping...
# Processing Record 7 of Set 15 | pekan
# Processing Record 8 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 9 of Set 15 | grebanu
# Processing Record 10 of Set 15 | serebryanyy bor
# Processing Record 11 of Set 15 | bacolod
# Processing Record 12 of Set 15 | rawah
# Processing Record 13 of Set 15 | ugoofaaru
# Processing Record 14 of Set 15 | daitari
# Processing Record 15 of Set 15 | gumushane
# City not found. Skipping...
# Processing Record 16 of Set 15 | tsaratanana
# Processing Record 17 of Set 15 | mount isa
# Processing Record 18 of Set 15 | ketchikan
# Processing Record 19 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 20 of Set 15 | amuntai
# Processing Record 21 of Set 15 | xingcheng
# Processing Record 22 of Set 15 | zhezkazgan
# Processing Record 23 of Set 15 | senanga
# Processing Record 24 of Set 15 | barra do garcas
# Processing Record 25 of Set 15 | gat
# Processing Record 26 of Set 15 | meadow lake
# Processing Record 27 of Set 15 | san isidro
# Processing Record 28 of Set 15 | porto novo
# Processing Record 29 of Set 15 | parczew
# Processing Record 30 of Set 15 | sivas
# Processing Record 31 of Set 15 | yarada
# Processing Record 32 of Set 15 | floro
# Processing Record 33 of Set 15 | bien hoa
# Processing Record 34 of Set 15 | qujing
# Processing Record 35 of Set 15 | moree
# Processing Record 36 of Set 15 | tres lagoas
# Processing Record 37 of Set 15 | prato
# Processing Record 38 of Set 15 | katha
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Recall that we can convert a list of dictionaries to a Pandas DataFrame using df = pd.DataFrame(list with dictionaries).
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Birao      CF  10.2849   22.7882     76.12        57          46
# 1          Beloha      MG -25.1667   45.0500     61.21        68           0
# 2         Mataura      NZ -46.1927  168.8643     58.48        57          66
# 3          Bethel      US  41.3712  -73.4140     67.17        86          90
# 4       Ustynivka      UA  47.9551   32.5367     41.45        36           0
# 5      Dargaville      NZ -35.9333  173.8833     58.95        96         100
# 6    Komsomolskiy      UZ  40.4272   71.7189     50.27        77          35
# 7       Cape Town      ZA -33.9258   18.4232     65.08        55           0
# 8           Natal      BR  -5.7950  -35.2094     80.82        78          20
# 9  Saint-Philippe      RE -21.3585   55.7679     69.35        83          35
#
#    Wind Speed Current Description
# 0        3.29    scattered clouds
# 1        5.61           clear sky
# 2        3.27       broken clouds
# 3        3.44     overcast clouds
# 4       12.17           clear sky
# 5        5.44     overcast clouds
# 6        1.90    scattered clouds
# 7        1.99           clear sky
# 8       13.80          few clouds
# 9        3.65          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
